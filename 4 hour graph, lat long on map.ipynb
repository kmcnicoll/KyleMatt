# %%
import json
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D




# graph the data
fig = plt.figure(1)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df["view"], df['grade'], df["price"])
ax.set_xlabel('view')
ax.set_ylabel('price')
ax.set_zlabel('grade')


# calculate the r-squared
rSquared = .512
print("the r-squared is: ", rSquared)
print("the coefficient (value of a) for age, weight, constant is: ", a)

# create a wiremesh for the plane that the predicted values will lie
xx, yy, zz = np.meshgrid(df["view"], df['grade'], df["price"])
combinedArrays = np.vstack((xx.flatten(), yy.flatten(), zz.flatten())).T
Z = combinedArrays.dot(a)

# graph the original data, predicted data, and wiremesh plane
fig = plt.figure(2)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df["view"], df['grade'], df["price"], color='r', label='Actual BP')
ax.scatter(X[:, 0], X[:, 1], predictedY, color='g', label='Predicted BP')
ax.plot_trisurf(combinedArrays[:, 0], combinedArrays[:, 1], Z, alpha=0.5)
ax.set_xlabel('View')
ax.set_ylabel('Grade')
ax.set_zlabel('Price')
ax.legend()
plt.show()
# Out:
# the r-squared is:  0.512
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-64e10201edd5> in <module>
#      18 rSquared = .512
#      19 print("the r-squared is: ", rSquared)
# ---> 20 print("the coefficient (value of a) for age, weight, constant is: ", a)
#      21
#      22 # create a wiremesh for the plane that the predicted values will lie
#
# NameError: name 'a' is not defined

# %%
plt.scatter(df["price"], df["waterfront"])
plt.xticks(rotation=45)
# Out:
# (array([-1000000.,        0.,  1000000.,  2000000.,  3000000.,  4000000.,
#          5000000.,  6000000.,  7000000.,  8000000.,  9000000.]),
#  <a list of 11 Text xticklabel objects>)

# %%
df.fillna(0)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014   221900.0         3       1.00         1180
# 1      6414100192   12/9/2014   538000.0         3       2.25         2570
# 2      5631500400   2/25/2015   180000.0         2       1.00          770
# 3      2487200875   12/9/2014   604000.0         4       3.00         1960
# 4      1954400510   2/18/2015   510000.0         3       2.00         1680
# 5      7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6      1321400060   6/27/2014   257500.0         3       2.25         1715
# 7      2008000270   1/15/2015   291850.0         3       1.50         1060
# 8      2414600126   4/15/2015   229500.0         3       1.00         1780
# 9      3793500160   3/12/2015   323000.0         3       2.50         1890
# 10     1736800520    4/3/2015   662500.0         3       2.50         3560
# ...

# %%
import statsmodels.api as sm

X = df["price"]
y = df["waterfront"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             waterfront   R-squared (uncentered):                     nan
# Model:                            OLS   Adj. R-squared (uncentered):                nan
# Method:                 Least Squares   F-statistic:                                nan
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):                         nan
# Time:                        10:42:08   Log-Likelihood:                             nan
# No. Observations:               21597   AIC:                                        nan
# Df Residuals:                   21596   BIC:                                        nan
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.004176  0.276295 -0.002386   0.067282     0.110230  0.023143
# view           0.011592  0.395734  0.078523   0.186451     0.282532  0.075298
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-bb7cc599c7da> in <module>
# ----> 1 logreg = LogisticRegression().fit(X,y)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1530
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1532                          accept_large_sparse=solver != 'liblinear')
#    1533         check_classification_targets(y)
#    1534         self.classes_ = np.unique(y)
#
# ...

# %%
plt.scatter(df["long"], df["lat"])
plt.xticks(rotation=45)
# Out:
# (array([-122.6, -122.4, -122.2, -122. , -121.8, -121.6, -121.4, -121.2]),
#  <a list of 8 Text xticklabel objects>)

# %%
import plotly.graph_objects as go

import pandas as pd


fig = go.Figure(data=go.Scattergeo(
        lon = df['long'],
        lat = df['lat'],
        mode = 'markers'
        ))

fig.update_layout(
        title = 'Kings County Housing Data',
        geo_scope='usa',
    )
fig.show()
# Out:
# <div>
#
#
#             <div id="1e00f79b-65e8-410b-9d65-0ab0a680d20f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e00f79b-65e8-410b-9d65-0ab0a680d20f")) {
#                     Plotly.newPlot(
#                         '1e00f79b-65e8-410b-9d65-0ab0a680d20f',
# ...

# %%
img = plt.imread('Screen Shot 2019-11-26 at 2.25.44 PM.png')
fig, ax = plt.subplots()
x = range(300)
ax.imshow(img, extent=[0, 400, 0, 300])
ax.plot(kind="scatter", x=df["long"],  y=df["lat"], c="price",
    cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.4, figsize=(10,7),
))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-172-27c60f3850da> in <module>
#       3 ax.plot(kind="scatter", x=df["long"],  y=df["lat"], c=df["price"],
#       4     cmap=plt.get_cmap("jet"),
# ----> 5     colorbar=True, alpha=0.4, figsize=(10,7),
#       6 )
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     169             if pos_only in kwargs:
# ...

# %%
import matplotlib.pyplot as plt
df.plot(kind="scatter", x="long",  y="lat", c="price",
    cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.4, figsize=(10,7),
)

plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np
import matplotlib.image as mpimg
img=mpimg.imread('Screen Shot 2019-11-26 at 2.25.44 PM.png')
df.plot(kind="scatter", x="long", y="lat",
    cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.4, figsize=(10,7),
)
plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

prices = df["price"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar()
cbar.ax.set_yticklabels(["$%dk"%(round(v/1000)) for v in tick_values], fontsize=14)
cbar.set_label('House Price', fontsize=16)

plt.legend(fontsize=16)
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-235-463de275eaa4> in <module>
#      12 prices = df["price"]
#      13 tick_values = np.linspace(prices.min(), prices.max(), 11)
# ---> 14 cbar = plt.colorbar()
#      15 cbar.ax.set_yticklabels(["$%dk"%(round(v/1000)) for v in tick_values], fontsize=14)
#      16 cbar.set_label('House Price', fontsize=16)
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2073         mappable = gci()
#    2074         if mappable is None:
# ...

# %%
fig, ax = plt.subplots()
x = range(300)
plt.imshow(img, extent=[0, 400, 0, 300])
df.plot(kind="scatter", x="long",  y="lat", c="price",
    cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.4, figsize=(10,7),
)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-250-5b0964eb22a5> in <module>
# ----> 1 df.plt(kind="scatter", x="long",  y="lat", c="price",
#       2     cmap=plt.get_cmap("jet"),
#       3     colorbar=True, alpha=0.4, figsize=(10,7),
#       4 )
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'plt'

# %%
im = plt.imread('Screen Shot 2019-11-26 at 2.25.44 PM.png')
df.plot(kind="scatter", x="long",  y="lat", c="price",
    cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.4, figsize=(10,7),
)

# %%
import numpy as np
import matplotlib.pyplot as plt

df.plot(kind="scatter", x="long",  y="lat", c="price",
    cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.4, figsize=(10,7),
)
img = plt.imread("Screen Shot 2019-11-26 at 2.25.44 PM.png")

ext = [-122.8, -120.5, 47.05, 47.8]
plt.imshow(img, zorder=0, extent=ext)

aspect=img.shape[0]/float(img.shape[1])*((ext[1]-ext[0])/(ext[3]-ext[2]))
plt.gca().set_aspect(aspect)

plt.show()

# %%
df["long"].max()
# Out:
# -121.315
