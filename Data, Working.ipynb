# %%
import pandas as pd

df = pd.read_excel (r'8th_all_050331.xls')
#8th is for year 2001-2002
#7th 1998-2000

# %%
df[100:500]
# Out:
#      pc   tc    Part                                              Table   QNx  \
# 100  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# 101  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# 102  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# 103  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# 104  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# 105  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# 106  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# 107  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# 108  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# 109  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# 110  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.20
# ...

# %% [markdown]
# added content
