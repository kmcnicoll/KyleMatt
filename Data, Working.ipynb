# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel (r'8th_all_050331.xls')
#8th is for year 2001-2002
#7th 1998-2000

# %%
df.head()
# Out:
#    pc   tc    Part                                              Table  QNx  \
# 0  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.1
# 1  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.1
# 2  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.1
# 3  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.1
# 4  8a  8a1  POLICE  1. Police personnel, by sex, and financial res...  1.1
#
#                    VLabel ISO3166_3    Country  year  NumValue       pop  \
# 0  Total police personnel       ALB    Albania  2001   13296.0   3132000
# 1  Total police personnel       ALB    Albania  2002   11987.0   3150000
# 2  Total police personnel       AUS  Australia  2001   57239.0  19414000
# 3  Total police personnel       AUS  Australia  2002   59812.0  19663000
# 4  Total police personnel       AUT    Austria  2001   25014.0   8032000
#
#          rate    QN
# 0  424.521073  1.01
# 1  380.539683  1.01
# ...

# %%
df[(df.VLabel == 'Albania') | ( df.year == 2001)]
# Out:
#       pc   tc     Part                                              Table  \
# 0     8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 1     8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 2     8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 4     8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 6     8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 9     8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 11    8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 13    8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 15    8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 17    8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 19    8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# 21    8a  8a1   POLICE  1. Police personnel, by sex, and financial res...
# ...

# %%
working=df.groupby(['Table'])

# %%
df["VLabel"][0]
# Out:
# 'Total police personnel'

# %%
working = df[(df.Table == '10. Persons convicted in the criminal courts, by type of crime')]
# |( df.year == 2001)]
working
# Out:
#       pc   tc    Part                                              Table  \
# 5772  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5773  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5774  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5775  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5776  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5777  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5778  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5779  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5780  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5781  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5782  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# 5783  8c  8c3  COURTS  10. Persons convicted in the criminal courts, ...
# ...

# %%
sns.regplot(x= 'rate', y="pop", data=sample);

# %%
sample = df[df.VLabel == "Total police personnel"]
df=sample
# Out:
# pc                                                          8a
# tc                                                         8a1
# Part                                                    POLICE
# Table        1. Police personnel, by sex, and financial res...
# QNx                                                        1.1
# VLabel                                  Total police personnel
# ISO3166_3                                                  AUT
# Country                                                Austria
# year                                                      2001
# NumValue                                                 25014
# pop                                                    8032000
# rate                                                   311.429
# QN                                                        1.01
# Name: 4, dtype: object

# %%
# sns.regplot(x= sample["rate"], y= working["rate"], data=sample,working);

# %%
# working_dict= {}
# for item in list(range(0,91)):
#      working_dict.update({sample.iloc[item]['Country'] : str(
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-127-d7335b90f102> in <module>
#       3 #      working_dict.update({sample.iloc[item]['Country'] : str(
#       4
# ----> 5 sample.iloc[item]['rate']
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# -> 2230             self._validate_integer(key, axis)
#    2231
#    2232             return self._get_loc(key, axis=axis)
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_excel (r'8th_all_050331.xls')
data = data.sample(50)
y = data[
X = data.drop(["mpg", "name", "origin"], axis=1)

scale = MinMaxScaler()
transformed = scale.fit_transform(X)
X = pd.DataFrame(transformed, columns = X.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-0087f74ab560> in <module>
#      15
#      16 scale = MinMaxScaler()
# ---> 17 transformed = scale.fit_transform(X)
#      18 X = pd.DataFrame(transformed, columns = X.columns)
#
# NameError: name 'X' is not defined
